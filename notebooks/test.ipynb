# %%
from api.application_features import ApplicationFeature

test = {
  "SK_ID_CURR": 252960,
  "TARGET": 0,
  "NAME_CONTRACT_TYPE": "Cash loans",
  "CODE_GENDER": "F",
  "FLAG_OWN_CAR": "N",
  "FLAG_OWN_REALTY": "N",
  "CNT_CHILDREN": 0,
  "AMT_INCOME_TOTAL": 121500.0,
  "AMT_CREDIT": 592560.0,
  "AMT_ANNUITY": 35937.0,
  "AMT_GOODS_PRICE": 450000.0,
  "NAME_TYPE_SUITE": "Family",
  "NAME_INCOME_TYPE": "Commercial associate",
  "NAME_EDUCATION_TYPE": "Secondary / secondary special",
  "NAME_FAMILY_STATUS": "Married",
  "NAME_HOUSING_TYPE": "House / apartment",
  "REGION_POPULATION_RELATIVE": 0.003069,
  "DAYS_BIRTH": -18026,
  "DAYS_EMPLOYED": -9152,
  "DAYS_REGISTRATION": -4003.0,
  "DAYS_ID_PUBLISH": -1580,
  "OWN_CAR_AGE": None,
  "FLAG_MOBIL": 1,
  "FLAG_EMP_PHONE": 1,
  "FLAG_WORK_PHONE": 0,
  "FLAG_CONT_MOBILE": 1,
  "FLAG_PHONE": 1,
  "FLAG_EMAIL": 0,
  "OCCUPATION_TYPE": "Laborers",
  "CNT_FAM_MEMBERS": 2.0,
  "REGION_RATING_CLIENT": 3,
  "REGION_RATING_CLIENT_W_CITY": 3,
  "WEEKDAY_APPR_PROCESS_START": "THURSDAY",
  "HOUR_APPR_PROCESS_START": 11,
  "REG_REGION_NOT_LIVE_REGION": 0,
  "REG_REGION_NOT_WORK_REGION": 0,
  "LIVE_REGION_NOT_WORK_REGION": 0,
  "REG_CITY_NOT_LIVE_CITY": 0,
  "REG_CITY_NOT_WORK_CITY": 0,
  "LIVE_CITY_NOT_WORK_CITY": 0,
  "ORGANIZATION_TYPE": "Agriculture",
  "EXT_SOURCE_1": None,
  "EXT_SOURCE_2": 0.117468848,
  "EXT_SOURCE_3": 0.365616507,
  "APARTMENTS_AVG": None,
  "BASEMENTAREA_AVG": None,
  "YEARS_BEGINEXPLUATATION_AVG": None,
  "YEARS_BUILD_AVG": None,
  "COMMONAREA_AVG": None,
  "ELEVATORS_AVG": None,
  "ENTRANCES_AVG": None,
  "FLOORSMAX_AVG": None,
  "FLOORSMIN_AVG": None,
  "LANDAREA_AVG": None,
  "LIVINGAPARTMENTS_AVG": None,
  "LIVINGAREA_AVG": None,
  "NONLIVINGAPARTMENTS_AVG": None,
  "NONLIVINGAREA_AVG": None,
  "FONDKAPREMONT_MODE": None,
  "HOUSETYPE_MODE": None,
  "TOTALAREA_MODE": None,
  "WALLSMATERIAL_MODE": None,
  "EMERGENCYSTATE_MODE": None,
  "OBS_30_CNT_SOCIAL_CIRCLE": 0.0,
  "DEF_30_CNT_SOCIAL_CIRCLE": 0.0,
  "OBS_60_CNT_SOCIAL_CIRCLE": 0.0,
  "DEF_60_CNT_SOCIAL_CIRCLE": 0.0,
  "DAYS_LAST_PHONE_CHANGE": -225.0,
  "FLAG_DOCUMENT_2": 0,
  "FLAG_DOCUMENT_3": 1,
  "FLAG_DOCUMENT_4": 0,
  "FLAG_DOCUMENT_5": 0,
  "FLAG_DOCUMENT_6": 0,
  "FLAG_DOCUMENT_7": 0,
  "FLAG_DOCUMENT_8": 0,
  "FLAG_DOCUMENT_9": 0,
  "FLAG_DOCUMENT_10": 0,
  "FLAG_DOCUMENT_11": 0,
  "FLAG_DOCUMENT_12": 0,
  "FLAG_DOCUMENT_13": 0,
  "FLAG_DOCUMENT_14": 0,
  "FLAG_DOCUMENT_15": 0,
  "FLAG_DOCUMENT_16": 0,
  "FLAG_DOCUMENT_17": 0,
  "FLAG_DOCUMENT_18": 0,
  "FLAG_DOCUMENT_19": 0,
  "FLAG_DOCUMENT_20": 0,
  "FLAG_DOCUMENT_21": 0,
  "AMT_REQ_CREDIT_BUREAU_HOUR": 0.0,
  "AMT_REQ_CREDIT_BUREAU_DAY": 0.0,
  "AMT_REQ_CREDIT_BUREAU_WEEK": 0.0,
  "AMT_REQ_CREDIT_BUREAU_MON": 0.0,
  "AMT_REQ_CREDIT_BUREAU_QRT": 0.0,
  "AMT_REQ_CREDIT_BUREAU_YEAR": 2.0,
  "bureau_records": [
    {
      "SK_ID_CURR": 252960,
      "SK_ID_BUREAU": 5676139,
      "CREDIT_ACTIVE": "Closed",
      "CREDIT_CURRENCY": "currency 1",
      "DAYS_CREDIT": -1012,
      "CREDIT_DAY_OVERDUE": 0,
      "DAYS_CREDIT_ENDDATE": -649.0,
      "DAYS_ENDDATE_FACT": -649.0,
      "AMT_CREDIT_MAX_OVERDUE": None,
      "CNT_CREDIT_PROLONG": 0,
      "AMT_CREDIT_SUM": 75726.0,
      "AMT_CREDIT_SUM_DEBT": 0.0,
      "AMT_CREDIT_SUM_LIMIT": 0.0,
      "AMT_CREDIT_SUM_OVERDUE": 0.0,
      "CREDIT_TYPE": "Consumer credit",
      "DAYS_CREDIT_UPDATE": -613,
      "AMT_ANNUITY": None,
      "bureau_balances": [
        {
          "SK_ID_BUREAU": 5676139,
          "MONTHS_BALANCE": -15,
          "STATUS": "C"
        }
      ]
    }
  ],
  "installments_payments": [
    {
      "SK_ID_PREV": 2737010,
      "SK_ID_CURR": 252960,
      "NUM_INSTALMENT_VERSION": 1.0,
      "NUM_INSTALMENT_NUMBER": 1,
      "DAYS_INSTALMENT": -1008.0,
      "DAYS_ENTRY_PAYMENT": -1010.0,
      "AMT_INSTALMENT": 92670.03,
      "AMT_PAYMENT": 92670.03
    }
  ],
  "pos_cash_balances": [
    {
      "SK_ID_PREV": 1235655,
      "SK_ID_CURR": 252960,
      "MONTHS_BALANCE": -2,
      "CNT_INSTALMENT": 6.0,
      "CNT_INSTALMENT_FUTURE": 0.0,
      "NAME_CONTRACT_STATUS": "Completed",
      "SK_DPD": 0,
      "SK_DPD_DEF": 0
    }
  ],
  "credit_card_balances": [
    {
      "SK_ID_PREV": 1710828,
      "SK_ID_CURR": 252960,
      "MONTHS_BALANCE": -80,
      "AMT_BALANCE": 173661.84,
      "AMT_CREDIT_LIMIT_ACTUAL": 180000,
      "AMT_DRAWINGS_ATM_CURRENT": 0.0,
      "AMT_DRAWINGS_CURRENT": 0.0,
      "AMT_DRAWINGS_OTHER_CURRENT": 0.0,
      "AMT_DRAWINGS_POS_CURRENT": 0.0,
      "AMT_INST_MIN_REGULARITY": 13455.9,
      "AMT_PAYMENT_CURRENT": 26100.0,
      "AMT_PAYMENT_TOTAL_CURRENT": 26100.0,
      "AMT_RECEIVABLE_PRINCIPAL": 166126.995,
      "AMT_RECIVABLE": 173661.84,
      "AMT_TOTAL_RECEIVABLE": 173661.84,
      "CNT_DRAWINGS_ATM_CURRENT": 0.0,
      "CNT_DRAWINGS_CURRENT": 0,
      "CNT_DRAWINGS_OTHER_CURRENT": 0.0,
      "CNT_DRAWINGS_POS_CURRENT": 0.0,
      "CNT_INSTALMENT_MATURE_CUM": 1.0,
      "NAME_CONTRACT_STATUS": "Active",
      "SK_DPD": 0,
      "SK_DPD_DEF": 0
    }
  ],
  "previous_applications": [
    {
      "SK_ID_PREV": 1919240,
      "SK_ID_CURR": 252960,
      "NAME_CONTRACT_TYPE": "Cash loans",
      "AMT_ANNUITY": 9476.955,
      "AMT_APPLICATION": 90000.0,
      "AMT_CREDIT": 95940.0,
      "AMT_DOWN_PAYMENT": None,
      "AMT_GOODS_PRICE": 90000.0,
      "WEEKDAY_APPR_PROCESS_START": "TUESDAY",
      "HOUR_APPR_PROCESS_START": 9,
      "FLAG_LAST_APPL_PER_CONTRACT": "Y",
      "NFLAG_LAST_APPL_IN_DAY": 1,
      "RATE_DOWN_PAYMENT": None,
      "RATE_INTEREST_PRIMARY": None,
      "RATE_INTEREST_PRIVILEGED": None,
      "NAME_CASH_LOAN_PURPOSE": "XNA",
      "NAME_CONTRACT_STATUS": "Approved",
      "DAYS_DECISION": -687,
      "NAME_PAYMENT_TYPE": "Cash through the bank",
      "CODE_REJECT_REASON": "XAP",
      "NAME_TYPE_SUITE": "Unaccompanied",
      "NAME_CLIENT_TYPE": "Repeater",
      "NAME_GOODS_CATEGORY": "XNA",
      "NAME_PORTFOLIO": "Cash",
      "NAME_PRODUCT_TYPE": "x-sell",
      "CHANNEL_TYPE": "AP+ (Cash loan)",
      "SELLERPLACE_AREA": 4,
      "NAME_SELLER_INDUSTRY": "XNA",
      "CNT_PAYMENT": 12.0,
      "NAME_YIELD_GROUP": "low_normal",
      "PRODUCT_COMBINATION": "Cash X-Sell: low",
      "DAYS_FIRST_DRAWING": 365243.0,
      "DAYS_FIRST_DUE": -657.0,
      "DAYS_LAST_DUE_1ST_VERSION": -327.0,
      "DAYS_LAST_DUE": -447.0,
      "DAYS_TERMINATION": -353.0,
      "NFLAG_INSURED_ON_APPROVAL": 1.0
    }
  ]
}

# %%
from oldapplication import ApplicationModel

modele = ApplicationModel.model_validate(test)

# %%
preprocessing = ApplicationFeature()

data = preprocessing.fit_transform(modele)

data.shape
# Out:
# (1, 155)
