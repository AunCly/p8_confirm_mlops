# %%
import pandas as pd
application = pd.read_csv('../data/rafined/application.csv', sep=',')
application
# Out:
#         SK_ID_CURR  app_TARGET  app_CNT_CHILDREN  app_AMT_INCOME_TOTAL  \
# 0           100002           1                 0              202500.0
# 1           100003           0                 0              270000.0
# 2           100004           0                 0               67500.0
# 3           100006           0                 0              135000.0
# 4           100007           0                 0              121500.0
# ...            ...         ...               ...                   ...
# 307506      456251           0                 0              157500.0
# 307507      456252           0                 0               72000.0
# 307508      456253           0                 0              153000.0
# 307509      456254           1                 0              171000.0
# 307510      456255           0                 0              157500.0
#
#         app_AMT_CREDIT  app_AMT_ANNUITY  app_AMT_GOODS_PRICE  \
# ...

# %%
import seaborn as sns
application.shape

# matrix = application.corr()
#
# sns.heatmap(matrix)
# Out:
# (307511, 368)
