# %% [markdown]
# # Cycle 5

# %% [markdown]
# Optimisation des hyperparamètres du modèle + fonction évaluation métier

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import re
import utils
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
application = pd.read_csv('../data/rafined/application.csv', sep=',')

# %%
X_train, X_test, y_train, y_test = utils.split_train_data(application, 'app_TARGET')

numeric_cols = X_train.select_dtypes(include=['int64', 'int32']).columns
X_train[numeric_cols] = X_train[numeric_cols].astype('float64')
X_test[numeric_cols] = X_test[numeric_cols].astype('float64')
X_train.columns = [re.sub(r'[ \[\]\{\}:",]', '_', col) for col in X_train.columns]
X_test.columns = [re.sub(r'[ \[\]\{\}:",]', '_', col) for col in X_test.columns]

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, make_scorer

def optimize_business_cost(y_true, y_pred_proba, fn_weight=10, fp_weight=1):

    thresholds = np.linspace(0.01, 0.99, 99)
    min_cost = float('inf')

    for t in thresholds:
        y_pred = (y_pred_proba >= t).astype(int)

        tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()

        cost = (fn * fn_weight) + (fp * fp_weight)

        if cost < min_cost:
            min_cost = cost

    # On retourne le coût en négatif car RandomizedSearchCV cherche à maximiser
    return -min_cost

business_scorer = make_scorer(optimize_business_cost, response_method='predict_proba')

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
import mlflow
import warnings
import datetime
import scipy.stats as stats

warnings.filterwarnings("ignore")

mlflow.set_experiment("Payment_fault_classification")
mlflow.sklearn.autolog()

mlflow.end_run()

neg_count, pos_count = y_train.value_counts()
scale_weight = neg_count / pos_count
lightgbm_model = LGBMClassifier(scale_pos_weight=scale_weight)

param_distributions = {
    'model__n_estimators': stats.randint(100, 800),
    'model__learning_rate': stats.loguniform(0.01, 0.3),
    'model__num_leaves': stats.randint(20, 150),
    'model__max_depth': stats.randint(3, 12),
    'model__min_child_samples': stats.randint(10, 100),
    'model__colsample_bytree': stats.uniform(0.5, 0.5),
    'model__subsample': stats.uniform(0.5, 0.5),
    'model__reg_alpha': stats.loguniform(1e-4, 10.0),
    'model__reg_lambda': stats.loguniform(1e-4, 10.0),
}

run_name = "Optimization_LGBM_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
with mlflow.start_run(run_name=run_name) as parent_run:

    mlflow.set_tags({
        'dataset': 'rafined',
        'execution_type': 'hyperparameter_search_with_custom_scoring',
        'model_name': lightgbm_model
    })

    scoring = {
        'business_cost': business_scorer,
        'auc': 'roc_auc',
    }

    random_search = RandomizedSearchCV(
        estimator=lightgbm_model,
        param_distributions=param_distributions,
        n_iter=10,
        cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
        scoring=scoring,
        refit='business_cost',
        n_jobs=-1,
        random_state=42
    )

    print("Début de l'optimisation des hyperparamètres...")

    random_search.fit(X_train, y_train)

    print(f"Meilleurs paramètres trouvés : {random_search.best_params_}")
    print(f"Meilleur score F1 (CV) : {random_search.best_score_}")
# Out:
# Début de l'optimisation des hyperparamètres...
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.393075 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 26732
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.525272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26702
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.288625 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26689
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.655330 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26732
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 355
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.333445 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26638
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.359025 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26708
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.641534 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 26702
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.351469 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26708
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.365054 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26689
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.360172 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26638
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 355
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.496547 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26708
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.363874 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26689
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.355159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26732
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.421053 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26638
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.413494 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26702
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180918
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.380233 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26732
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.357200 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26708
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 356
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.423635 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26689
# [LightGBM] [Info] Number of data points in the train set: 196806, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432480
# [LightGBM] [Info] Start training from score -2.432480
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Info] Number of positive: 15888, number of negative: 180919
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.442828 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26638
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.445776 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26702
# [LightGBM] [Info] Number of data points in the train set: 196807, number of used features: 355
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432485
# [LightGBM] [Info] Start training from score -2.432485
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# ...
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Info] Number of positive: 19860, number of negative: 226148
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055906 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26667
# [LightGBM] [Info] Number of data points in the train set: 246008, number of used features: 356
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080729 -> initscore=-2.432482
# [LightGBM] [Info] Start training from score -2.432482
# 2026/08/11 09:53:26 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# 2026/08/11 09:53:28 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# 2026/08/11 09:53:41 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/08/11 09:53:43 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2026/08/11 09:53:43 INFO mlflow.sklearn.utils: Logging the 5 best runs, 5 runs will be omitted.
# 🏃 View run abrasive-skunk-27 at: http://127.0.0.1:5000/#/experiments/1/runs/39d9f43f8b7f4227aeb2b2d56d9bd1b7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 🏃 View run marvelous-cod-443 at: http://127.0.0.1:5000/#/experiments/1/runs/b3a9f46f5e954687a647d151de3d1ae4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 🏃 View run gentle-shrimp-773 at: http://127.0.0.1:5000/#/experiments/1/runs/f0bd4cf30e9647d1bb082444b498283f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 🏃 View run wistful-shrike-448 at: http://127.0.0.1:5000/#/experiments/1/runs/7a7f9643334e4896837f1f9e3a2aebda
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 🏃 View run gregarious-finch-352 at: http://127.0.0.1:5000/#/experiments/1/runs/1dd0b9132d4a468e95c50c250e64040e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# Meilleurs paramètres trouvés : {'model__colsample_bytree': np.float64(0.6872700594236812), 'model__learning_rate': np.float64(0.2536999076681772), 'model__max_depth': 10, 'model__min_child_samples': 70, 'model__n_estimators': 120, 'model__num_leaves': 122, 'model__reg_alpha': np.float64(0.01694976823788473), 'model__reg_lambda': np.float64(0.0003161364550529618), 'model__subsample': np.float64(0.7296244459829335)}
# Meilleur score F1 (CV) : -24807.6
# 🏃 View run Optimization_LGBM_20260811-095046 at: http://127.0.0.1:5000/#/experiments/1/runs/ae769df8ba174c97afc2ad0ea4d5c5a5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
def find_best_threshold(model, X, y_true, fn_weight=10, fp_weight=1):
    y_pred_proba = model.predict_proba(X)[:, 1]
    thresholds = np.linspace(0.01, 0.99, 99)

    min_cost = float('inf')
    best_t = 0.5

    for t in thresholds:
        print(f"Seuil : {t} : ")
        y_pred = (y_pred_proba >= t).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        cost = (fn * fn_weight) + (fp * fp_weight)
        print(confusion_matrix(y_true, y_pred))
        if cost < min_cost:
            min_cost = cost
            best_t = t

    return best_t, min_cost

# %%
best_model = random_search.best_estimator_

optimal_threshold, final_cost = find_best_threshold(best_model, X_train, y_train)

print(f"Seuil de décision optimal à utiliser en production : {optimal_threshold:.2f}")

# On logge manuellement cette information métier cruciale dans MLflow
with mlflow.start_run(run_id=mlflow.last_active_run().info.run_id):
    mlflow.log_param("optimal_decision_threshold", optimal_threshold)
    mlflow.log_metric("final_train_business_cost", final_cost)
# Out:
# [LightGBM] [Warning] Unknown parameter: model__n_estimators
# [LightGBM] [Warning] Unknown parameter: model__num_leaves
# [LightGBM] [Warning] Unknown parameter: model__learning_rate
# [LightGBM] [Warning] Unknown parameter: model__colsample_bytree
# [LightGBM] [Warning] Unknown parameter: model__max_depth
# [LightGBM] [Warning] Unknown parameter: model__min_child_samples
# [LightGBM] [Warning] Unknown parameter: model__reg_lambda
# [LightGBM] [Warning] Unknown parameter: model__reg_alpha
# [LightGBM] [Warning] Unknown parameter: model__subsample
# Seuil : 0.01 :
# [[     0 226148]
#  [     0  19860]]
# Seuil : 0.02 :
# [[    12 226136]
#  [     0  19860]]
# Seuil : 0.03 :
# [[   151 225997]
#  [     0  19860]]
# Seuil : 0.04 :
# [[   576 225572]
#  [     0  19860]]
# Seuil : 0.05 :
# [[  1502 224646]
#  [     0  19860]]
# Seuil : 0.060000000000000005 :
# [[  3119 223029]
#  [     0  19860]]
# Seuil : 0.06999999999999999 :
# [[  5323 220825]
#  [     2  19858]]
# Seuil : 0.08 :
# [[  7952 218196]
#  [     5  19855]]
# Seuil : 0.09 :
# [[ 11182 214966]
#  [     9  19851]]
# Seuil : 0.09999999999999999 :
# [[ 14827 211321]
#  [    14  19846]]
# Seuil : 0.11 :
# [[ 18767 207381]
#  [    26  19834]]
# Seuil : 0.12 :
# [[ 22962 203186]
#  [    42  19818]]
# Seuil : 0.13 :
# [[ 27202 198946]
#  [    55  19805]]
# Seuil : 0.14 :
# [[ 31741 194407]
#  [    86  19774]]
# Seuil : 0.15000000000000002 :
# [[ 36306 189842]
#  [   119  19741]]
# Seuil : 0.16 :
# [[ 40844 185304]
#  [   152  19708]]
# Seuil : 0.17 :
# [[ 45434 180714]
#  [   184  19676]]
# Seuil : 0.18000000000000002 :
# [[ 49931 176217]
#  [   232  19628]]
# Seuil : 0.19 :
# [[ 54382 171766]
#  [   278  19582]]
# Seuil : 0.2 :
# [[ 58985 167163]
#  [   339  19521]]
# Seuil : 0.21000000000000002 :
# [[ 63424 162724]
#  [   395  19465]]
# Seuil : 0.22 :
# [[ 67947 158201]
#  [   466  19394]]
# Seuil : 0.23 :
# [[ 72187 153961]
#  [   541  19319]]
# Seuil : 0.24000000000000002 :
# [[ 76391 149757]
#  [   615  19245]]
# Seuil : 0.25 :
# [[ 80434 145714]
#  [   717  19143]]
# Seuil : 0.26 :
# [[ 84656 141492]
#  [   821  19039]]
# Seuil : 0.27 :
# [[ 88675 137473]
#  [   912  18948]]
# Seuil : 0.28 :
# [[ 92710 133438]
#  [  1006  18854]]
# Seuil : 0.29000000000000004 :
# [[ 96553 129595]
#  [  1119  18741]]
# Seuil : 0.3 :
# [[100317 125831]
#  [  1218  18642]]
# Seuil : 0.31 :
# [[104022 122126]
#  [  1336  18524]]
# Seuil : 0.32 :
# [[107712 118436]
#  [  1443  18417]]
# Seuil : 0.33 :
# [[111309 114839]
#  [  1567  18293]]
# Seuil : 0.34 :
# [[114890 111258]
#  [  1696  18164]]
# Seuil : 0.35000000000000003 :
# [[118425 107723]
#  [  1835  18025]]
# Seuil : 0.36000000000000004 :
# [[121888 104260]
#  [  1990  17870]]
# Seuil : 0.37 :
# [[125333 100815]
#  [  2141  17719]]
# Seuil : 0.38 :
# [[128615  97533]
#  [  2324  17536]]
# Seuil : 0.39 :
# [[131804  94344]
#  [  2502  17358]]
# Seuil : 0.4 :
# [[135022  91126]
#  [  2674  17186]]
# Seuil : 0.41000000000000003 :
# [[138081  88067]
#  [  2859  17001]]
# Seuil : 0.42000000000000004 :
# [[141217  84931]
#  [  3022  16838]]
# Seuil : 0.43 :
# [[144292  81856]
#  [  3206  16654]]
# Seuil : 0.44 :
# [[147198  78950]
#  [  3397  16463]]
# Seuil : 0.45 :
# [[150138  76010]
#  [  3576  16284]]
# Seuil : 0.46 :
# [[153005  73143]
#  [  3774  16086]]
# Seuil : 0.47000000000000003 :
# [[155869  70279]
#  [  4018  15842]]
# Seuil : 0.48000000000000004 :
# [[158718  67430]
#  [  4239  15621]]
# Seuil : 0.49 :
# [[161428  64720]
#  [  4483  15377]]
# Seuil : 0.5 :
# [[164030  62118]
#  [  4699  15161]]
# Seuil : 0.51 :
# [[166738  59410]
#  [  4948  14912]]
# Seuil : 0.52 :
# [[169277  56871]
#  [  5186  14674]]
# Seuil : 0.53 :
# [[171804  54344]
#  [  5454  14406]]
# Seuil : 0.54 :
# [[174271  51877]
#  [  5724  14136]]
# Seuil : 0.55 :
# [[176741  49407]
#  [  5990  13870]]
# Seuil : 0.56 :
# [[179161  46987]
#  [  6284  13576]]
# Seuil : 0.5700000000000001 :
# [[181478  44670]
#  [  6582  13278]]
# Seuil : 0.5800000000000001 :
# [[183795  42353]
#  [  6896  12964]]
# Seuil : 0.59 :
# [[186032  40116]
#  [  7224  12636]]
# Seuil : 0.6 :
# [[188283  37865]
#  [  7534  12326]]
# Seuil : 0.61 :
# [[190469  35679]
#  [  7859  12001]]
# Seuil : 0.62 :
# [[192631  33517]
#  [  8220  11640]]
# Seuil : 0.63 :
# [[194719  31429]
#  [  8568  11292]]
# Seuil : 0.64 :
# [[196801  29347]
#  [  8932  10928]]
# Seuil : 0.65 :
# [[198827  27321]
#  [  9318  10542]]
# Seuil : 0.66 :
# [[200650  25498]
#  [  9662  10198]]
# Seuil : 0.67 :
# [[202504  23644]
#  [ 10010   9850]]
# Seuil : 0.68 :
# [[204219  21929]
#  [ 10406   9454]]
# Seuil : 0.6900000000000001 :
# [[206003  20145]
#  [ 10848   9012]]
# Seuil : 0.7000000000000001 :
# [[207706  18442]
#  [ 11264   8596]]
# Seuil : 0.7100000000000001 :
# [[209344  16804]
#  [ 11696   8164]]
# Seuil : 0.72 :
# [[210980  15168]
#  [ 12130   7730]]
# Seuil : 0.73 :
# [[212460  13688]
#  [ 12558   7302]]
# Seuil : 0.74 :
# [[213921  12227]
#  [ 13052   6808]]
# Seuil : 0.75 :
# [[215298  10850]
#  [ 13514   6346]]
# Seuil : 0.76 :
# [[216659   9489]
#  [ 13997   5863]]
# Seuil : 0.77 :
# [[217885   8263]
#  [ 14440   5420]]
# Seuil : 0.78 :
# [[219095   7053]
#  [ 14948   4912]]
# Seuil : 0.79 :
# [[220132   6016]
#  [ 15438   4422]]
# Seuil : 0.8 :
# [[221188   4960]
#  [ 15918   3942]]
# Seuil : 0.81 :
# [[222053   4095]
#  [ 16366   3494]]
# Seuil : 0.8200000000000001 :
# [[222865   3283]
#  [ 16807   3053]]
# Seuil : 0.8300000000000001 :
# [[223584   2564]
#  [ 17263   2597]]
# Seuil : 0.8400000000000001 :
# [[224215   1933]
#  [ 17667   2193]]
# Seuil : 0.85 :
# [[224727   1421]
#  [ 18091   1769]]
# Seuil : 0.86 :
# [[225158    990]
#  [ 18496   1364]]
# Seuil : 0.87 :
# [[225463    685]
#  [ 18832   1028]]
# Seuil : 0.88 :
# [[225743    405]
#  [ 19162    698]]
# Seuil : 0.89 :
# [[225916    232]
#  [ 19403    457]]
# Seuil : 0.9 :
# [[226041    107]
#  [ 19588    272]]
# Seuil : 0.91 :
# [[226106     42]
#  [ 19725    135]]
# Seuil : 0.92 :
# [[226135     13]
#  [ 19802     58]]
# Seuil : 0.93 :
# [[226145      3]
#  [ 19842     18]]
# Seuil : 0.9400000000000001 :
# [[226148      0]
#  [ 19857      3]]
# Seuil : 0.9500000000000001 :
# [[226148      0]
#  [ 19859      1]]
# Seuil : 0.9600000000000001 :
# [[226148      0]
#  [ 19860      0]]
# Seuil : 0.97 :
# [[226148      0]
#  [ 19860      0]]
# Seuil : 0.98 :
# [[226148      0]
#  [ 19860      0]]
# Seuil : 0.99 :
# [[226148      0]
#  [ 19860      0]]
# Seuil de décision optimal à utiliser en production : 0.52
# 🏃 View run Optimization_LGBM_20260811-095046 at: http://127.0.0.1:5000/#/experiments/1/runs/ae769df8ba174c97afc2ad0ea4d5c5a5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
best_model = random_search.best_estimator_
importances = best_model.feature_importances_
features_names = best_model.feature_name_

utils.show_importances(importances, features_names, 20)

# %%
local_path = mlflow.artifacts.download_artifacts(
    artifact_uri="models:/payment_fault_classificator/1",
    dst_path="../models/compiled"
)

print(f"Modèle téléchargé ici : {local_path}")
# Out:
# Modèle téléchargé ici : /Users/auncly/Documents/Formation data scientist/8 - Confirmez vos compétences en MLOps/notebooks/mon_modele_local/

# %%
sample = X_test.sample(1, random_state=42)
sample.to_json(orient='index')
# Out:
# '{"14343":{"SK_ID_CURR":116731.0,"app_CNT_CHILDREN":0.0,"app_AMT_INCOME_TOTAL":270000.0,"app_AMT_CREDIT":1031053.5,"app_AMT_ANNUITY":34204.5,"app_AMT_GOODS_PRICE":783000.0,"app_REGION_POPULATION_RELATIVE":0.006233,"app_DAYS_BIRTH":-17143.0,"app_DAYS_EMPLOYED":-476.0,"app_DAYS_REGISTRATION":-2549.0,"app_DAYS_ID_PUBLISH":-331.0,"app_OWN_CAR_AGE":14.0,"app_FLAG_MOBIL":1.0,"app_FLAG_EMP_PHONE":1.0,"app_FLAG_WORK_PHONE":0.0,"app_FLAG_CONT_MOBILE":1.0,"app_FLAG_PHONE":0.0,"app_FLAG_EMAIL":0.0,"app_CNT_FAM_MEMBERS":2.0,"app_REGION_RATING_CLIENT":2.0,"app_REGION_RATING_CLIENT_W_CITY":2.0,"app_HOUR_APPR_PROCESS_START":10.0,"app_REG_REGION_NOT_LIVE_REGION":0.0,"app_REG_REGION_NOT_WORK_REGION":0.0,"app_LIVE_REGION_NOT_WORK_REGION":0.0,"app_REG_CITY_NOT_LIVE_CITY":0.0,"app_REG_CITY_NOT_WORK_CITY":0.0,"app_LIVE_CITY_NOT_WORK_CITY":0.0,"app_EXT_SOURCE_1":null,"app_EXT_SOURCE_2":0.5664555615,"app_EXT_SOURCE_3":0.4776491549,"app_APARTMENTS_AVG":0.0577,"app_BASEMENTAREA_AVG":0.0271,"app_YEARS_BEGINEXPLUATATION_AVG":0.9737,"app_YEARS_BUILD_AVG":0.6396,"app_COMMONAREA_AVG":0.0102,"app_ELEVATORS_AVG":0.0,"app_ENTRANCES_AVG":0.1034,"app_FLOORSMAX_AVG":0.1458,"app_FLOORSMIN_AVG":0.1875,"app_LANDAREA_AVG":0.0865,"app_LIVINGAPARTMENTS_AVG":0.0466,"app_LIVINGAREA_AVG":0.0443,"app_NONLIVINGAPARTMENTS_AVG":0.0019,"app_NONLIVINGAREA_AVG":0.0299,"app_APARTMENTS_MODE":0.0336,"app_BASEMENTAREA_MODE":0.0271,"app_YEARS_BEGINEXPLUATATION_MODE":0.9737,"app_YEARS_BUILD_MODE":0.6537,"app_COMMONAREA_MODE":0.0031,"app_ELEVATORS_MODE":0.0,"app_ENTRANCES_MODE":0.069,"app_FLOORSMAX_MODE":0.125,"app_FLOORSMIN_MODE":0.1667,"app_LANDAREA_MODE":0.0652,"app_LIVINGAPARTMENTS_MODE":0.0285,"app_LIVINGAREA_MODE":0.0255,"app_NONLIVINGAPARTMENTS_MODE":0.0,"app_NONLIVINGAREA_MODE":0.0175,"app_APARTMENTS_MEDI":0.0583,"app_BASEMENTAREA_MEDI":0.0271,"app_YEARS_BEGINEXPLUATATION_MEDI":0.9737,"app_YEARS_BUILD_MEDI":0.6444,"app_COMMONAREA_MEDI":0.0102,"app_ELEVATORS_MEDI":0.0,"app_ENTRANCES_MEDI":0.1034,"app_FLOORSMAX_MEDI":0.1458,"app_FLOORSMIN_MEDI":0.1875,"app_LANDAREA_MEDI":0.088,"app_LIVINGAPARTMENTS_MEDI":0.0475,"app_LIVINGAREA_MEDI":0.0451,"app_NONLIVINGAPARTMENTS_MEDI":0.0019,"app_NONLIVINGAREA_MEDI":0.0306,"app_TOTALAREA_MODE":0.0228,"app_OBS_30_CNT_SOCIAL_CIRCLE":5.0,"app_DEF_30_CNT_SOCIAL_CIRCLE":2.0,"app_OBS_60_CNT_SOCIAL_CIRCLE":5.0,"app_DEF_60_CNT_SOCIAL_CIRCLE":2.0,"app_DAYS_LAST_PHONE_CHANGE":-1457.0,"app_FLAG_DOCUMENT_2":0.0,"app_FLAG_DOCUMENT_3":1.0,"app_FLAG_DOCUMENT_4":0.0,"app_FLAG_DOCUMENT_5":0.0,"app_FLAG_DOCUMENT_6":0.0,"app_FLAG_DOCUMENT_7":0.0,"app_FLAG_DOCUMENT_8":0.0,"app_FLAG_DOCUMENT_9":0.0,"app_FLAG_DOCUMENT_10":0.0,"app_FLAG_DOCUMENT_11":0.0,"app_FLAG_DOCUMENT_12":0.0,"app_FLAG_DOCUMENT_13":0.0,"app_FLAG_DOCUMENT_14":0.0,"app_FLAG_DOCUMENT_15":0.0,"app_FLAG_DOCUMENT_16":0.0,"app_FLAG_DOCUMENT_17":0.0,"app_FLAG_DOCUMENT_18":0.0,"app_FLAG_DOCUMENT_19":0.0,"app_FLAG_DOCUMENT_20":0.0,"app_FLAG_DOCUMENT_21":0.0,"app_AMT_REQ_CREDIT_BUREAU_HOUR":0.0,"app_AMT_REQ_CREDIT_BUREAU_DAY":0.0,"app_AMT_REQ_CREDIT_BUREAU_WEEK":0.0,"app_AMT_REQ_CREDIT_BUREAU_MON":2.0,"app_AMT_REQ_CREDIT_BUREAU_QRT":0.0,"app_AMT_REQ_CREDIT_BUREAU_YEAR":3.0,"app_code_gender":0.0,"app_own_car":1.0,"app_own_realty":1.0,"app_education_type":3.0,"app_ratio_days_employed_vs_days_birth":0.0277664353,"app_ratio_income_vs_credit":0.2618680796,"app_ratio_income_total_vs_fam_number":135000.0,"app_ratio_annuity_vs_income_total":0.1266833333,"app_ratio_children_vs_family":0.0,"app_age":46.9349760438,"app_NAME_CONTRACT_TYPE_Cash_loans":true,"app_NAME_CONTRACT_TYPE_Revolving_loans":false,"app_CODE_GENDER_F":false,"app_CODE_GENDER_M":true,"app_CODE_GENDER_XNA":false,"app_FLAG_OWN_CAR_N":false,"app_FLAG_OWN_CAR_Y":true,"app_FLAG_OWN_REALTY_N":false,"app_FLAG_OWN_REALTY_Y":true,"app_NAME_TYPE_SUITE_Children":false,"app_NAME_TYPE_SUITE_Family":false,"app_NAME_TYPE_SUITE_Group_of_people":false,"app_NAME_TYPE_SUITE_Other_A":false,"app_NAME_TYPE_SUITE_Other_B":false,"app_NAME_TYPE_SUITE_Spouse__partner":false," ...

# %%
sample.shape
# Out:
# (1, 367)
